# %% [markdown]
# <a href="https://colab.research.google.com/github/joewebkid/ai2media-docs/blob/main/1.1.%20Ai2media_how_to_use.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Create workspace
#
# Для создания нового рабочего пространства используем панель администратора.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Необходимо добавить поисковое слово - Term.
#
# Источники из которых будет происходить поиск наших данных - Sources.
#
# Для добавления нового источника необходимо перейти в раздел Link, выбрать тип и категорию источника.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В поле User- пользователь. Необходимо выбрать текущего пользователя, который сейчас авторизован.
